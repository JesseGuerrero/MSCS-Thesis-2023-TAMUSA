# %%
from Dataset import *
from base_mutators import *
from operators import *

# %%
from Dataset import *
with open("./humanCOCOSmall.json", "r") as f:
    data = dict(json.load(f))
    dataset = Dataset(data, ["showcase"])
    dataset.setRootDir("./mutations/")
    wordsList = {
        "tree": "tre3",
        "food": "fo@d",
        "of" : "0f"
    }
    replaceFromDictionary(dataset, wordsList, word_change_limit=1)
    dataset.saveToFile()

# %%
from Dataset import *
with open("HumanCOCOSmallCaption.json", "r") as f:
    data = dict(json.load(f))
    dataset = Dataset(data, ["showcase"])
    dataset.setRootDir("./mutations/")
    wordsList = ["bins", "colorful", "fruit", "bread", "trays", "plastic"]
    replaceWordListWithRandomSelf(dataset, wordsList, "", word_change_limit=1)
    dataset.saveToFile()

# %%
# populateRandomWord(1000)

# %%
import json
def populateSynonymsAPI(lower:int, higher:int):
    with open("mutation_data/random_word.json") as f:
        data = dict(json.load(f))
        for i in range(lower, higher):
            getSynonymAPI(data["word"][i])

def populateAntonymsAPI(lower:int, higher:int):
    with open("mutation_data/random_word.json") as f:
        data = dict(json.load(f))
        for i in range(lower, higher):
            getAntonymAPI(data["word"][i])

# %%
# populateSynonymsAPI(0, 900)##
# populateSynonymsAPI(900, 3000) ##
# populateAntonymsAPI(0, 900)##
# populateAntonymsAPI(900, 3000)
# Out:
# {'word': 'engine', 'synonyms': ['locomotive', 'locomotive engine', 'railway locomotive']}
# {'word': 'engineer', 'synonyms': ['direct', 'mastermind', 'orchestrate', 'organise', 'organize', 'applied scientist', 'technologist', 'engine driver', 'locomotive engineer', 'railroad engineer']}
# {'word': 'engineering', 'synonyms': ['applied science', 'engineering science', 'technology', 'engine room']}
# {'word': 'english', 'synonyms': ['english language', 'english people', 'side']}
# {'word': 'enhance', 'synonyms': ['heighten', 'raise']}
# {'word': 'enjoy', 'synonyms': ['bask', 'relish', 'savor', 'savour', 'love', 'delight', 'revel']}
# {'word': 'enormous', 'synonyms': ['tremendous']}
# {'word': 'enough', 'synonyms': ['sufficiency', 'plenty', 'adequate']}
# {'word': 'ensure', 'synonyms': ['ascertain', 'assure', 'check', 'control', 'insure', 'see', 'see to it', 'guarantee', 'secure']}
# {'word': 'enter', 'synonyms': ['come in', 'get in', 'get into', 'go in', 'go into', 'move into', 'figure', 'enrol', 'enroll', 'inscribe', 'recruit', 'embark', 'accede', 'infix', 'insert', 'introduce', 'participate', 'put down', 'record']}
# {'word': 'enterprise', 'synonyms': ['enterprisingness', 'go-ahead', 'initiative', 'endeavor', 'endeavour']}
# {'word': 'entertainment', 'synonyms': ['amusement']}
# {'word': 'entire', 'synonyms': ['full', 'total', 'intact', 'integral', 'stallion']}
# {'word': 'entirely', 'synonyms': ['alone', 'exclusively', 'only', 'solely', 'all', 'altogether', 'completely', 'right', 'totally', 'whole', 'wholly']}
# {'word': 'entrance', 'synonyms': ['spellbind', 'entranceway', 'entree', 'entry', 'entryway', 'entering', 'incoming', 'ingress', 'becharm', 'beguile', 'bewitch', 'captivate', 'capture', 'catch', 'charm', 'enamor', 'enamour', 'enchant', 'fascinate', 'trance']}
# {'word': 'entry', 'synonyms': ['accounting entry', 'ledger entry', 'entrance', 'entranceway', 'entree', 'entryway', 'debut', 'first appearance', 'introduction', 'launching', 'unveiling', 'entering', 'incoming', 'ingress', 'submission']}
# {'word': 'environment', 'synonyms': ['environs', 'surround', 'surroundings']}
# {'word': 'environmental', 'synonyms': []}
# {'word': 'episode', 'synonyms': ['installment', 'instalment', 'sequence']}
# {'word': 'equal', 'synonyms': ['compeer', 'match', 'peer', 'be', 'rival', 'touch', 'equalise', 'equalize', 'equate', 'adequate']}
# {'word': 'equally', 'synonyms': ['evenly', 'as', 'every bit']}
# {'word': 'equipment', 'synonyms': []}
# {'word': 'era', 'synonyms': ['epoch', 'geological era', 'earned run average']}
# {'word': 'error', 'synonyms': ['erroneous belief', 'fault', 'mistake', 'misplay', 'erroneousness', 'wrongdoing', 'computer error']}
# {'word': 'escape', 'synonyms': ['get away', 'escape cock', 'escape valve', 'relief valve', 'safety valve', 'elude', 'dodging', 'evasion', 'miss', 'leak', 'leakage', 'outflow', 'break away', 'bunk', 'fly the coop', 'head for the hills', 'hightail it', 'lam', 'run', 'run away', 'scarper', 'scat', 'take to the woods', 'turn tail', 'break loose', 'escapism', 'flight', 'get by', 'get off', 'get out']}
# {'word': 'especially', 'synonyms': ['particularly', 'peculiarly', 'specially']}
# {'word': 'essay', 'synonyms': ['assay', 'attempt', 'seek', 'try', 'examine', 'prove', 'test', 'try out']}
# {'word': 'essential', 'synonyms': ['necessary', 'necessity', 'requirement', 'requisite', 'all-important', 'all important', 'crucial', 'of the essence', 'indispensable', 'substantive']}
# {'word': 'essentially', 'synonyms': ['basically', 'fundamentally']}
# {'word': 'establish', 'synonyms': ['lay down', 'make', 'build', 'give', 'instal', 'install', 'set up', 'base', 'found', 'ground', 'constitute', 'institute', 'plant', 'demonstrate', 'prove', 'shew', 'show', 'launch']}
# {'word': 'establishment', 'synonyms': ['administration', 'brass', 'governance', 'governing body', 'organisation', 'organization', 'institution', 'validation', 'ecesis', 'constitution', 'formation']}
# {'word': 'estate', 'synonyms': ['estate of the realm', 'the three estates', 'acres', 'demesne', 'land', 'landed estate']}
# {'word': 'estimate', 'synonyms': ['calculate', 'count on', 'figure', 'forecast', 'reckon', 'approximation', 'estimation', 'idea', 'approximate', 'gauge', 'guess', 'judge', 'appraisal']}
# {'word': 'etc', 'synonyms': []}
# {'word': 'ethics', 'synonyms': ['moral philosophy', 'ethical motive', 'morality', 'morals']}
# {'word': 'ethnic', 'synonyms': ['cultural', 'ethnical', 'heathen', 'heathenish', 'pagan']}
# {'word': 'european', 'synonyms': []}
# {'word': 'evaluate', 'synonyms': ['judge', 'pass judgment', 'appraise', 'assess', 'measure', 'valuate', 'value']}
# {'word': 'evaluation', 'synonyms': ['rating', 'valuation']}
# {'word': 'even', 'synonyms': ['still', 'yet', 'level', 'tied', 'regular', 'even out', 'flush', 'eve', 'evening', 'eventide', 'fifty-fifty']}
# {'word': 'evening', 'synonyms': ['eve', 'even', 'eventide']}
# {'word': 'event', 'synonyms': ['consequence', 'effect', 'issue', 'outcome', 'result', 'upshot', 'case']}
# {'word': 'eventually', 'synonyms': ['finally']}
# {'word': 'ever', 'synonyms': ['always', "e'er", 'ever so', 'of all time']}
# {'word': 'every', 'synonyms': []}
# {'word': 'everybody', 'synonyms': []}
# {'word': 'everyday', 'synonyms': ['casual', 'daily', 'mundane', 'quotidian', 'routine', 'unremarkable', 'workaday']}
# {'word': 'everyone', 'synonyms': []}
# {'word': 'everything', 'synonyms': []}
# {'word': 'everywhere', 'synonyms': ['all over', 'everyplace']}
# {'word': 'evidence', 'synonyms': ['bear witness', 'prove', 'show', 'testify', 'attest', 'certify', 'demonstrate', 'manifest', 'tell', 'grounds']}
# {'word': 'evolution', 'synonyms': ['organic evolution', 'phylogenesis', 'phylogeny', 'development']}
# {'word': 'evolve', 'synonyms': ['develop', 'germinate', 'acquire']}
# {'word': 'exact', 'synonyms': ['demand', 'accurate', 'precise', 'claim', 'take']}
# {'word': 'exactly', 'synonyms': ['just', 'precisely', 'properly', 'incisively', 'on the button', 'on the dot', 'on the nose']}
# {'word': 'examination', 'synonyms': ['exam', 'test', 'testing', 'scrutiny', 'examen', 'interrogation', 'interrogatory']}
# {'word': 'examine', 'synonyms': ['essay', 'prove', 'test', 'try', 'try out', 'see', 'analyse', 'analyze', 'canvass', 'study', 'probe']}
# {'word': 'example', 'synonyms': ['model', 'exemplar', 'good example', 'case', 'instance', 'illustration', 'representative', 'deterrent example', 'lesson', 'object lesson', 'exercise']}
# {'word': 'exceed', 'synonyms': ['surpass', 'transcend', 'go past', 'overstep', 'pass', 'top', 'outdo', 'outgo', 'outmatch', 'outperform', 'outstrip', 'surmount']}
# {'word': 'excellent', 'synonyms': ['fantabulous', 'first-class', 'ripping', 'splendid']}
# {'word': 'except', 'synonyms': ['demur', 'exclude', 'leave off', 'leave out', 'omit', 'take out']}
# {'word': 'exception', 'synonyms': ['elision', 'exclusion']}
# {'word': 'exchange', 'synonyms': ['change', 'commute', 'convert', 'interchange', 'replace', 'substitute', 'central', 'telephone exchange', 'commutation', 'substitution', 'rally', 'switch', 'switch over']}
# {'word': 'exciting', 'synonyms': []}
# {'word': 'executive', 'synonyms': ['administrator', 'executive director']}
# {'word': 'exercise', 'synonyms': ['drill', 'practice', 'practice session', 'recitation', 'practise', 'employment', 'usage', 'use', 'utilisation', 'utilization', 'exercising', 'physical exercise', 'physical exertion', 'workout', 'work out', 'work', 'example', 'do', 'exert']}
# {'word': 'exhibit', 'synonyms': ['display', 'expose', 'showing', 'demo', 'demonstrate', 'present', 'show', 'march', 'parade']}
# {'word': 'exhibition', 'synonyms': ['expo', 'exposition']}
# {'word': 'exist', 'synonyms': ['live', 'subsist', 'survive', 'be']}
# {'word': 'existence', 'synonyms': ['being', 'beingness', 'face of the earth', 'cosmos', 'creation', 'macrocosm', 'universe', 'world']}
# {'word': 'existing', 'synonyms': ['existent']}
# {'word': 'expand', 'synonyms': ['amplify', 'blow up', 'inflate', 'dilate', 'elaborate', 'enlarge', 'expatiate', 'exposit', 'expound', 'flesh out', 'lucubrate', 'extend', 'spread out', 'boom', 'flourish', 'thrive']}
# {'word': 'expansion', 'synonyms': ['expanding upon', 'elaboration', 'enlargement']}
# {'word': 'expect', 'synonyms': ['anticipate', 'ask', 'require', 'await', 'look', 'wait', 'bear', 'carry', 'gestate', 'have a bun in the oven']}
# {'word': 'expectation', 'synonyms': ['outlook', 'prospect', 'arithmetic mean', 'expected value', 'first moment', 'anticipation']}
# {'word': 'expense', 'synonyms': ['disbursal', 'disbursement', 'write down', 'write off']}
# {'word': 'expensive', 'synonyms': []}
# {'word': 'experience', 'synonyms': ['get', 'have', 'receive', 'go through', 'see', 'feel', 'know', 'live']}
# {'word': 'experiment', 'synonyms': ['experimentation', 'try out']}
# {'word': 'expert', 'synonyms': ['adept', 'good', 'practiced', 'proficient', 'skilful', 'skillful', 'technical']}
# {'word': 'explain', 'synonyms': ['excuse', 'explicate']}
# {'word': 'explanation', 'synonyms': ['account']}
# {'word': 'explode', 'synonyms': ['blow up', 'detonate', 'set off', 'irrupt', 'break loose', 'burst forth', 'burst']}
# {'word': 'explore', 'synonyms': ['research', 'search']}
# {'word': 'explosion', 'synonyms': ['blowup', 'detonation', 'burst', 'plosion']}
# {'word': 'expose', 'synonyms': ['display', 'exhibit', 'disclose', 'uncover', 'endanger', 'peril', 'queer', 'scupper', 'break', 'bring out', 'discover', 'divulge', 'give away', 'let on', 'let out', 'reveal', 'unwrap', 'unmasking', 'debunk']}
# {'word': 'exposure', 'synonyms': ['vulnerability', 'photo', 'photograph', 'pic', 'picture']}
# {'word': 'express', 'synonyms': ['extract', 'press out', 'state', 'give tongue to', 'utter', 'verbalise', 'verbalize', 'carry', 'convey', 'express mail', 'expressage', 'limited', 'evince', 'show']}
# {'word': 'expression', 'synonyms': ['locution', 'saying', 'verbal expression', 'verbalism', 'formula', 'aspect', 'face', 'facial expression', 'look', 'formulation', 'manifestation', 'reflection', 'reflexion', 'construction', 'grammatical construction']}
# {'word': 'extend', 'synonyms': ['broaden', 'widen', 'offer', 'expand', 'continue', 'cover', 'stretch', 'stretch out', 'unfold', 'exsert', 'hold out', 'put out', 'stretch forth', 'carry', 'gallop', 'poke out', 'reach out', 'strain', 'go', 'lead', 'pass', 'run', 'draw out', 'prolong', 'protract']}
# {'word': 'extension', 'synonyms': ['denotation', 'reference', 'annex', 'annexe', 'wing', 'lengthiness', 'prolongation', 'elongation', 'propagation', 'extension phone', 'telephone extension', 'extension service', 'university extension', 'file name extension', 'filename extension']}
# {'word': 'extensive', 'synonyms': ['extended', 'across-the-board', 'all-embracing', 'all-encompassing', 'all-inclusive', 'blanket', 'broad', 'encompassing', 'panoptic', 'wide']}
# {'word': 'extent', 'synonyms': []}
# {'word': 'external', 'synonyms': ['international', 'outside', 'extraneous']}
# {'word': 'extra', 'synonyms': ['special', 'spear carrier', 'supernumerary', 'additional', 'excess', 'redundant', 'spare', 'supererogatory', 'superfluous', 'surplus', 'duplicate']}
# {'word': 'extraordinary', 'synonyms': ['over-the-top', 'sinful']}
# {'word': 'extreme', 'synonyms': ['utmost', 'uttermost', 'extreme point', 'extremum']}
# {'word': 'extremely', 'synonyms': ['highly', 'deathly', 'exceedingly', 'super']}
# {'word': 'eye', 'synonyms': ['oculus', 'optic', 'eyeball', 'center', 'centre', 'heart', 'middle']}
# {'word': 'fabric', 'synonyms': ['cloth', 'material', 'textile', 'framework']}
# {'word': 'face', 'synonyms': ['grimace', 'case', 'font', 'fount', 'typeface', 'confront', 'aspect', 'expression', 'facial expression', 'look', 'side', 'front', 'human face', 'boldness', 'brass', 'cheek', 'nerve', 'face up', 'present']}
# {'word': 'facility', 'synonyms': ['installation', 'readiness', 'adeptness', 'adroitness', 'deftness', 'quickness']}
# {'word': 'fact', 'synonyms': []}
# {'word': 'factor', 'synonyms': ['agent', 'broker', 'cistron', 'gene', 'component', 'constituent', 'element', 'ingredient', 'divisor', 'factor in', 'factor out']}
# {'word': 'factory', 'synonyms': ['manufactory', 'manufacturing plant', 'mill']}
# {'word': 'faculty', 'synonyms': ['mental faculty', 'module', 'staff']}
# {'word': 'fade', 'synonyms': ['disappearance', 'wither', 'melt', 'slice', 'slicing', 'languish', 'blow over', 'evanesce', 'fleet', 'pass', 'pass off']}
# {'word': 'fail', 'synonyms': ['betray', 'go wrong', 'miscarry', 'neglect', 'break', 'break down', 'conk out', 'die', 'give out', 'give way', 'go', 'go bad', 'run out', 'bomb', 'flunk', 'flush it']}
# {'word': 'failure', 'synonyms': ['loser', 'nonstarter', 'unsuccessful person', 'bankruptcy']}
# {'word': 'fair', 'synonyms': ['clean', 'bonnie', 'bonny', 'comely', 'sightly', 'fairish', 'reasonable', 'just', 'evenhandedly', 'fairly', 'honest', 'bazaar', 'average', 'mediocre', 'middling', 'carnival', 'funfair']}
# {'word': 'fairly', 'synonyms': ['evenhandedly', 'fair', 'jolly', 'middling', 'moderately', 'passably', 'pretty', 'reasonably', 'somewhat', 'clean']}
# {'word': 'faith', 'synonyms': ['religion', 'religious belief', 'trust', 'organized religion']}
# {'word': 'fall', 'synonyms': ['come down', 'descend', 'go down', 'capitulation', 'surrender', 'accrue', 'pin', 'precipitate', 'fall down', 'downfall', 'flow', 'hang', 'light', 'dip', 'drop', 'free fall', 'shine', 'strike', 'decrease', 'diminish', 'lessen', 'settle', 'declension', 'declination', 'decline', 'declivity', 'descent', 'downslope', 'autumn', 'crepuscle', 'crepuscule', 'dusk', 'evenfall', 'gloam', 'gloaming', 'nightfall', 'twilight', 'spill', 'tumble', 'come', 'devolve', 'pass', 'return']}
# {'word': 'false', 'synonyms': ['assumed', 'fictitious', 'fictive', 'pretended', 'put on', 'sham', 'off-key', 'sour', 'fake', 'faux', 'imitation', 'simulated', 'mistaken', 'untrue', 'delusive', 'faithlessly', 'traitorously', 'treacherously', 'treasonably']}
# {'word': 'familiar', 'synonyms': ['conversant', 'intimate', 'familiar spirit', 'associate', 'companion', 'comrade', 'fellow']}
# {'word': 'family', 'synonyms': ['home', 'house', 'household', 'menage', 'family line', 'folk', 'kinfolk', 'kinsfolk', 'phratry', 'sept', 'crime syndicate', 'mob', 'syndicate', 'kin', 'kinsperson', 'fellowship', 'category', 'class', 'family unit']}
# {'word': 'famous', 'synonyms': ['celebrated', 'famed', 'far-famed', 'illustrious', 'notable', 'noted', 'renowned']}
# {'word': 'fan', 'synonyms': ['rooter', 'sports fan', 'winnow', 'buff', 'devotee', 'lover']}
# {'word': 'fantasy', 'synonyms': ['phantasy', 'fantasise', 'fantasize', 'fancy', 'illusion']}
# {'word': 'far', 'synonyms': ['alir', 'army for the liberation of rwanda', 'former armed forces', 'interahamwe']}
# {'word': 'farm', 'synonyms': ['grow', 'produce', 'raise']}
# {'word': 'farmer', 'synonyms': ['granger', 'husbandman', 'sodbuster', 'fannie farmer', 'fannie merritt farmer', 'james leonard farmer']}
# {'word': 'fashion', 'synonyms': ['forge', 'manner', 'mode', 'style', 'way']}
# {'word': 'fast', 'synonyms': ['firm', 'loyal', 'truehearted', 'tight', 'immobile', 'flying', 'quick', 'fasting', 'debauched', 'degenerate', 'degraded', 'dissipated', 'dissolute', 'libertine', 'profligate', 'riotous']}
# {'word': 'fat', 'synonyms': ['fatten', 'fatten out', 'fatten up', 'fill out', 'flesh out', 'plump', 'plump out', 'juicy', 'fertile', 'productive', 'rich', 'avoirdupois', 'blubber', 'fatness', 'adipose tissue', 'fatty tissue', 'fatty']}
# {'word': 'fate', 'synonyms': ['designate', 'destine', 'doom', 'destiny', 'circumstances', 'fortune', 'lot', 'luck', 'portion']}
# {'word': 'father', 'synonyms': ['padre', 'begetter', 'male parent', 'church father', 'father of the church', 'forefather', 'sire', 'beget', 'bring forth', 'engender', 'generate', 'get', 'mother', 'don', 'father-god', 'fatherhood', 'beginner', 'founder', 'founding father']}
# {'word': 'fault', 'synonyms': ['error', 'mistake', 'defect', 'flaw', 'demerit', 'break', 'faulting', 'fracture', 'geological fault', 'shift', 'blame']}
# {'word': 'favor', 'synonyms': ['favour', 'privilege', 'prefer', 'party favor', 'party favour']}
# {'word': 'favorite', 'synonyms': ['best-loved', 'favored', 'favourite', 'pet', 'preferent', 'preferred', 'front-runner', 'darling', 'dearie', 'deary', 'ducky']}
# {'word': 'fear', 'synonyms': ['revere', 'reverence', 'venerate', 'dread', 'care', 'concern', 'awe', 'veneration', 'fearfulness', 'fright']}
# {'word': 'feature', 'synonyms': ['characteristic', 'feature film', 'feature of speech', 'have', 'feature article', 'boast', 'sport', 'lineament']}
# {'word': 'federal', 'synonyms': ['fed', 'federal official', 'union', 'federal soldier', 'union soldier']}
# {'word': 'fee', 'synonyms': ['bung', 'tip']}
# {'word': 'feed', 'synonyms': ['provender', 'eat', 'prey', 'give', 'feed in', 'fertilise', 'fertilize', 'course', 'flow', 'run', 'feast']}
# {'word': 'feel', 'synonyms': ['feeling', 'flavor', 'flavour', 'look', 'smell', 'spirit', 'tone', 'finger', 'find', 'sense', 'palpate', 'tactile property', 'experience']}
# {'word': 'feeling', 'synonyms': ['feel', 'flavor', 'flavour', 'look', 'smell', 'spirit', 'tone', 'intuitive feeling', 'belief', 'impression', 'notion', 'opinion', 'tactile sensation', 'tactual sensation', 'touch', 'touch sensation']}
# {'word': 'fellow', 'synonyms': ['mate', 'beau', 'boyfriend', 'swain', 'colleague', 'confrere', 'associate', 'companion', 'comrade', 'familiar', 'buster', 'dude', 'blighter', 'bloke', 'chap', 'cuss', 'fella', 'feller', 'gent', 'lad']}
# {'word': 'female', 'synonyms': ['distaff', 'female person']}
# {'word': 'fence', 'synonyms': ['argue', 'contend', 'debate', 'fence in', 'fencing', 'palisade', 'surround', 'wall']}
# {'word': 'few', 'synonyms': []}
# {'word': 'fewer', 'synonyms': []}
# {'word': 'fiber', 'synonyms': ['fibre', 'character', 'roughage', 'vulcanized fiber']}
# {'word': 'fiction', 'synonyms': ['fable', 'fabrication']}
# {'word': 'field', 'synonyms': ['bailiwick', 'discipline', 'field of study', 'study', 'subject', 'subject area', 'subject field', 'field of operation', 'line of business', 'field of view', 'area', 'arena', 'domain', 'orbit', 'sphere', 'field of force', 'force field', 'athletic field', 'playing area', 'playing field', 'airfield', 'flying field', 'landing field', 'champaign', 'plain', 'battlefield', 'battleground', 'field of battle', 'field of honor', 'field of operations', 'theater', 'theater of operations', 'theatre', 'theatre of operations']}
# {'word': 'fifteen', 'synonyms': ['15', 'xv']}
# {'word': 'fifth', 'synonyms': ['5th', 'fifth part', 'one-fifth', 'twenty percent']}
# {'word': 'fifty', 'synonyms': ['50', 'l', 'fifty dollar bill']}
# {'word': 'fight', 'synonyms': ['contend', 'struggle', 'battle', 'conflict', 'engagement', 'combat', 'fighting', 'scrap', 'agitate', 'campaign', 'crusade', 'press', 'push', 'defend', 'fight back', 'fight down', 'oppose', 'competitiveness']}
# {'word': 'fighter', 'synonyms': ['battler', 'belligerent', 'combatant', 'scrapper', 'attack aircraft', 'fighter aircraft', 'champion', 'hero', 'paladin']}
# {'word': 'fighting', 'synonyms': ['active', 'combat-ready', 'combat', 'fight', 'scrap']}
# {'word': 'figure', 'synonyms': ['digit', 'calculate', 'count on', 'estimate', 'forecast', 'reckon', 'enter', 'fig', 'design', 'pattern', 'number', 'name', 'public figure', 'anatomy', 'bod', 'build', 'chassis', 'flesh', 'form', 'frame', 'human body', 'material body', 'physical body', 'physique', 'shape', 'soma', 'envision', 'fancy', 'image', 'picture', 'project', 'see', 'visualise', 'visualize', 'figure of speech', 'trope', 'cipher', 'compute', 'cypher', 'work out']}
# {'word': 'file', 'synonyms': ['register', 'indian file', 'single file', 'charge', 'lodge', 'file cabinet', 'filing cabinet', 'data file', 'file away']}
# {'word': 'fill', 'synonyms': ['fill up', 'make full', 'filling', 'occupy', 'conform to', 'fit', 'fulfil', 'fulfill', 'meet', 'satisfy', 'take', 'replete', 'sate', 'satiate']}
# {'word': 'film', 'synonyms': ['shoot', 'take', 'flick', 'motion-picture show', 'motion picture', 'movie', 'moving-picture show', 'moving picture', 'pic', 'picture', 'picture show', 'plastic film', 'photographic film', 'celluloid', 'cinema']}
# {'word': 'final', 'synonyms': ['last', 'final exam', 'final examination', 'concluding', 'terminal', 'net']}
# {'word': 'finally', 'synonyms': ['in conclusion', 'last', 'lastly', 'at last', 'at long last', 'in the end', 'ultimately', 'eventually']}
# {'word': 'finance', 'synonyms': []}
# {'word': 'financial', 'synonyms': ['fiscal']}
# {'word': 'find', 'synonyms': ['discovery', 'uncovering', 'bump', 'chance', 'encounter', 'happen', 'detect', 'discover', 'notice', 'observe', 'feel', 'see', 'witness', 'recover', 'regain', 'retrieve', 'find oneself', 'get', 'incur', 'obtain', 'receive', 'breakthrough', 'ascertain', 'determine', 'find out', 'come up', 'get hold', 'line up', 'rule']}
# {'word': 'finding', 'synonyms': ['determination']}
# {'word': 'fine', 'synonyms': ['amercement', 'mulct', 'all right', 'alright', 'ok', 'very well', 'ticket', 'delicately', 'exquisitely', 'finely', 'cool', 'hunky-dory', 'o.k.', 'okay']}
# {'word': 'finger', 'synonyms': ['digit', "finger's breadth", 'fingerbreadth', 'feel', 'thumb']}
# {'word': 'finish', 'synonyms': ['coating', 'finishing', 'conclusion', 'ending', 'eat up', 'polish off', 'end up', 'fetch up', 'finish up', 'land up', 'wind up', 'close', 'finale', 'finis', 'last', 'stopping point', 'cultivation', 'culture', 'polish', 'refinement', 'cease', 'end', 'stop', 'terminate', 'complete', 'destination', 'goal']}
# {'word': 'fire', 'synonyms': ['arouse', 'elicit', 'enkindle', 'evoke', 'kindle', 'provoke', 'raise', 'fuel', 'open fire', 'discharge', 'go off', 'flame', 'flaming', 'ignite', 'light', 'ardor', 'ardour', 'fervency', 'fervidness', 'fervor', 'fervour', 'flame up', 'firing', 'attack', 'blast', 'flack', 'flak', 'can', 'dismiss', 'displace', 'force out', 'give notice', 'give the axe', 'give the sack', 'sack', 'send away', 'terminate', 'burn', 'burn down']}
# {'word': 'firm', 'synonyms': ['steady', 'unfluctuating', 'business firm', 'house', 'firmly', 'steadfastly', 'unwaveringly', 'fast', 'loyal', 'truehearted', 'steadfast', 'stiff', 'unbendable', 'unfaltering', 'unshakable', 'unwavering', 'immobile', 'strong', 'tauten', 'solid']}
# {'word': 'first', 'synonyms': ['first base', '1st', 'inaugural', 'initiative', 'initiatory', 'maiden', 'beginning', 'commencement', 'get-go', 'kickoff', 'offset', 'outset', 'showtime', 'start', 'starting time', 'foremost', 'world-class', 'first gear', 'low', 'low gear', 'number 1', 'number one', 'first of all', 'first off', 'firstly', 'first-class honours degree']}
# {'word': 'fish', 'synonyms': ['pisces', 'angle', 'pisces the fishes']}
# {'word': 'fishing', 'synonyms': ['sportfishing']}
# {'word': 'fit', 'synonyms': ['accommodate', 'suit', 'primed', 'set', 'convulsion', 'paroxysm', 'conform to', 'fill', 'fulfil', 'fulfill', 'meet', 'satisfy', 'match', 'burst', 'conniption', 'scene', 'tantrum', 'go', 'equip', 'fit out', 'outfit', 'agree', 'check', 'correspond', 'gibe', 'jibe', 'tally']}
# {'word': 'fitness', 'synonyms': ['fittingness', 'physical fitness']}
# {'word': 'five', 'synonyms': ['basketball team', 'five-spot', '5', 'v', 'cinque', 'fin', 'fivesome', 'little phoebe', 'pentad', 'phoebe', 'quint', 'quintet', 'quintuplet']}
# {'word': 'fix', 'synonyms': ['localisation', 'localization', 'locating', 'location', 'hole', 'jam', 'kettle of fish', 'mess', 'muddle', 'pickle', 'bushel', 'doctor', 'furbish up', 'mend', 'repair', 'restore', 'touch on', 'deposit', 'posit', 'situate', 'desex', 'desexualise', 'desexualize', 'sterilise', 'sterilize', 'unsex', 'define', 'determine', 'limit', 'set', 'specify', 'gear up', 'prepare', 'ready', 'set up', 'get', 'pay back', 'pay off', 'fixing', 'fixture', 'mending', 'reparation', 'cook', 'make', 'fasten', 'secure', 'fixate']}
# {'word': 'flag', 'synonyms': ['signal flag', 'ease off', 'ease up', 'slacken off', 'flagstone', 'pin', 'masthead', 'fleur-de-lis', 'iris', 'sword lily', 'droop', 'sag', 'swag']}
# {'word': 'flame', 'synonyms': ['flare', 'fire', 'flaming']}
# {'word': 'flat', 'synonyms': ['flat tire', 'flatbed', 'flatcar', 'apartment', '2-dimensional', 'two-dimensional', 'directly', 'straight', 'categoric', 'categorical', 'unconditional', 'mat', 'matt', 'matte', 'matted', 'bland', 'flavorless', 'flavourless', 'insipid', 'savorless', 'savourless', 'vapid', 'level', 'plane', 'monotone', 'monotonic', 'monotonous', 'prostrate', 'compressed']}
# {'word': 'flavor', 'synonyms': ['flavour', 'feel', 'feeling', 'look', 'smell', 'spirit', 'tone', 'nip', 'relish', 'sapidity', 'savor', 'savour', 'smack', 'tang', 'season']}
# {'word': 'flee', 'synonyms': ['fly', 'take flight']}
# {'word': 'flesh', 'synonyms': ['anatomy', 'bod', 'build', 'chassis', 'figure', 'form', 'frame', 'human body', 'material body', 'physical body', 'physique', 'shape', 'soma', 'pulp']}
# {'word': 'flight', 'synonyms': ['flying', 'flight of stairs', 'flight of steps', 'fledge', 'trajectory', 'escape']}
# {'word': 'float', 'synonyms': ['air bladder', 'swim bladder', 'be adrift', 'blow', 'drift', "plasterer's float", 'swim', 'ice-cream float', 'ice-cream soda']}
# {'word': 'floor', 'synonyms': ['flooring', 'ball over', 'blow out of the water', 'shock', 'take aback', 'base', 'coldcock', 'deck', 'dump', 'knock down', 'trading floor', 'level', 'storey', 'story']}
# {'word': 'flow', 'synonyms': ['stream', 'fall', 'hang', 'catamenia', 'menses', 'menstruation', 'menstruum', 'period', 'flux', 'flow rate', 'rate of flow', 'current', 'flowing', 'menstruate', 'course', 'feed', 'run']}
# {'word': 'flower', 'synonyms': ['bloom', 'blossom', 'efflorescence', 'flush', 'heyday', 'peak', 'prime']}
# {'word': 'focus', 'synonyms': ['focalise', 'focalize', 'centering', 'direction', 'focal point', 'focusing', 'focussing', 'center', 'centre', 'concentrate', 'pore', 'rivet', 'concenter', 'concentre', 'stress', 'nidus', 'sharpen']}
# {'word': 'folk', 'synonyms': ['common people', 'folks', 'family', 'family line', 'kinfolk', 'kinsfolk', 'phratry', 'sept', 'ethnic music', 'folk music', 'tribe']}
# {'word': 'follow', 'synonyms': ['postdate', 'pursue', 'travel along', 'keep abreast', 'keep up', 'trace', 'adopt', 'espouse', 'take after', 'stick to', 'stick with', 'fall out', 'keep an eye on', 'observe', 'watch', 'watch over', 'be', 'come after', 'succeed', 'abide by', 'comply', 'accompany', 'play along', 'come', 'conform to', 'surveil', 'survey']}
# {'word': 'following', 'synonyms': ['followers', 'next', 'undermentioned', 'chase', 'pursual', 'pursuit']}
# {'word': 'food', 'synonyms': ['solid food', 'food for thought', 'intellectual nourishment', 'nutrient']}
# {'word': 'foot', 'synonyms': ['base', 'foundation', 'fundament', 'groundwork', 'substructure', 'understructure', 'pick', 'metrical foot', 'metrical unit', 'foot up', 'human foot', 'pes', 'ft', 'invertebrate foot', 'hoof', 'hoof it', 'leg it', 'animal foot', 'infantry']}
# {'word': 'football', 'synonyms': ['football game']}
# {'word': 'for', 'synonyms': []}
# {'word': 'force', 'synonyms': ['effect', 'personnel', 'forcefulness', 'strength', 'force-out', 'force out', 'force play', 'coerce', 'hale', 'pressure', 'squeeze', 'drive', 'ram', 'impel', 'push', 'thrust', 'wedge', 'military force', 'military group', 'military unit', 'power', 'violence', 'storm']}
# {'word': 'foreign', 'synonyms': ['extraneous', 'strange', 'alien']}
# {'word': 'forest', 'synonyms': ['afforest', 'wood', 'woods', 'timber', 'timberland', 'woodland']}
# {'word': 'forever', 'synonyms': ['always', 'constantly', 'incessantly', 'perpetually', 'eternally', 'everlastingly', 'evermore', 'forever and a day']}
# {'word': 'forget', 'synonyms': ['leave', 'blank out', 'block', 'draw a blank', 'bury']}
# {'word': 'form', 'synonyms': ['cast', 'shape', 'pattern', 'descriptor', 'signifier', 'word form', 'forge', 'mold', 'mould', 'work', 'configuration', 'conformation', 'contour', 'imprint', 'class', 'course', 'grade', 'organise', 'organize', 'strain', 'var.', 'variant', 'kind', 'sort', 'variety', 'manakin', 'manikin', 'mannequin', 'mannikin', 'spring', 'take form', 'take shape', 'anatomy', 'bod', 'build', 'chassis', 'figure', 'flesh', 'frame', 'human body', 'material body', 'physical body', 'physique', 'soma', 'constitute', 'make', 'phase']}
# {'word': 'formal', 'synonyms': ['ball', 'conventional', 'schematic', 'dinner dress', 'dinner gown', 'evening gown', 'courtly', 'stately']}
# {'word': 'formation', 'synonyms': ['geological formation', 'constitution', 'establishment', 'organisation', 'organization', 'shaping']}
# {'word': 'former', 'synonyms': ['erstwhile', 'old', 'one-time', 'onetime', 'quondam', 'sometime', 'early', 'other', 'late', 'previous']}
# {'word': 'formula', 'synonyms': ['expression', 'convention', 'normal', 'pattern', 'rule', 'chemical formula', 'recipe']}
# {'word': 'forth', 'synonyms': ['forward', 'onward', 'forth river', 'away', 'off']}
# {'word': 'fortune', 'synonyms': ['luck', 'circumstances', 'destiny', 'fate', 'lot', 'portion', 'chance', 'hazard']}
# {'word': 'forward', 'synonyms': ['forth', 'onward', 'fore', 'send on', 'forrad', 'forrard', 'forwards', 'frontward', 'frontwards', 'ahead', 'forrader', 'onwards', 'advancing', 'forward-moving']}
# {'word': 'found', 'synonyms': ['base', 'establish', 'ground', 'constitute', 'institute', 'plant', 'launch', 'set up']}
# {'word': 'foundation', 'synonyms': ['grounding', 'base', 'foot', 'fundament', 'groundwork', 'substructure', 'understructure', 'foundation garment', 'basis', 'cornerstone', 'creation', 'founding', 'initiation', 'innovation', 'instauration', 'institution', 'introduction', 'origination']}
# {'word': 'founder', 'synonyms': ['fall flat', 'fall through', 'flop', 'laminitis', 'break', 'cave in', 'collapse', 'fall in', 'give', 'give way', 'beginner', 'father', 'founding father']}
# {'word': 'four', 'synonyms': ['4', 'iv', 'four-spot', 'foursome', 'little joe', 'quadruplet', 'quartet', 'quatern', 'quaternary', 'quaternion', 'quaternity', 'tetrad']}
# {'word': 'fourth', 'synonyms': ['fourthly', '4th', 'quaternary', 'fourth part', 'one-fourth', 'one-quarter', 'quarter', 'quartern', 'twenty-five percent']}
# {'word': 'frame', 'synonyms': ['frame of reference', 'cast', 'couch', 'put', 'redact', 'compose', 'draw up', 'frame up', 'inning', 'skeletal system', 'skeleton', 'systema skeletale', 'ensnare', 'entrap', 'set up', 'border', 'frame in', 'framing', 'skeletal frame', 'underframe', 'anatomy', 'bod', 'build', 'chassis', 'figure', 'flesh', 'form', 'human body', 'material body', 'physical body', 'physique', 'shape', 'soma', 'framework']}
# {'word': 'framework', 'synonyms': ['model', 'theoretical account', 'frame', 'fabric']}
# {'word': 'free', 'synonyms': ['spare', 'give up', 'release', 'relinquish', 'resign', 'detached', 'disembarrass', 'rid', 'disengage', 'dislodge', 'liberate', 'loose', 'unloose', 'unloosen', 'unblock', 'unfreeze', 'discharge', 'barren', 'destitute', 'devoid', 'innocent', 'free people', 'liberal', 'complimentary', 'costless', 'gratis', 'gratuitous', 'exempt', 'relieve', 'absolve']}
# {'word': 'freedom', 'synonyms': ['exemption']}
# {'word': 'freeze', 'synonyms': ['freeze down', 'freeze out', 'halt', 'suspend', 'block', 'immobilise', 'immobilize', 'stop dead', 'frost', 'freezing']}
# {'word': 'french', 'synonyms': ['french people', 'gallic', 'daniel chester french']}
# {'word': 'frequency', 'synonyms': ['frequence', 'oftenness', 'absolute frequency', 'relative frequency']}
# {'word': 'frequent', 'synonyms': ['haunt', 'buy at', 'patronise', 'patronize', 'shop', 'shop at', 'sponsor']}
# {'word': 'frequently', 'synonyms': ['oft', 'often', 'oftentimes', 'ofttimes']}
# {'word': 'fresh', 'synonyms': ['new', 'novel', 'sweet', 'impertinent', 'impudent', 'overbold', 'sassy', 'saucy', 'smart', 'wise', 'unused', 'invigorated', 'refreshed', 'reinvigorated', 'clean', 'freshly', 'newly', 'unfermented', 'bracing', 'brisk', 'refreshful', 'refreshing', 'tonic']}
# {'word': 'friend', 'synonyms': ['quaker', 'admirer', 'booster', 'champion', 'protagonist', 'supporter', 'ally', 'acquaintance']}
# {'word': 'friendly', 'synonyms': ['well-disposed', 'well disposed']}
# {'word': 'friendship', 'synonyms': ['friendly relationship']}
# {'word': 'from', 'synonyms': []}
# {'word': 'front', 'synonyms': ['forepart', 'front end', 'figurehead', 'front man', 'nominal head', 'straw man', 'strawman', 'movement', 'social movement', 'face', 'look', 'presence', 'breast', 'battlefront', 'front line']}
# {'word': 'fruit', 'synonyms': ['yield']}
# {'word': 'frustration', 'synonyms': ['foiling', 'thwarting', 'defeat']}
# {'messages': 'The API is unreachable, please contact the API provider', 'info': 'Your Client (working) ---> Gateway (working) ---> API (not working)'}
# {'word': 'full', 'synonyms': ['wax', 'full-of-the-moon', 'full moon', 'full phase of the moon', 'fully', 'to the full', 'entire', 'total', 'good', 'wide', 'wide-cut', 'replete', 'broad']}
# {'word': 'fully', 'synonyms': ['full', 'to the full', 'amply', 'in full']}
# {'word': 'fun', 'synonyms': ['merriment', 'playfulness', 'play', 'sport']}
# {'word': 'function', 'synonyms': ['office', 'part', 'role', 'go', 'operate', 'run', 'work', 'map', 'mapping', 'mathematical function', 'single-valued function', 'affair', 'occasion', 'social function', 'social occasion', 'serve', 'purpose', 'use', 'procedure', 'routine', 'subprogram', 'subroutine', 'officiate']}
# {'word': 'fund', 'synonyms': ['monetary fund', 'investment company', 'investment firm', 'investment trust', 'stock', 'store']}
# {'word': 'fundamental', 'synonyms': ['profound', 'rudimentary', 'underlying', 'first harmonic', 'fundamental frequency', 'cardinal', 'central', 'key', 'primal']}
# {'word': 'funding', 'synonyms': ['backing', 'financial backing', 'financial support', 'support', 'financing']}
# {'word': 'funeral', 'synonyms': ['obsequy']}
# {'word': 'funny', 'synonyms': ['funny remark', 'funny story', 'good story', 'curious', 'odd', 'peculiar', 'queer', 'rum', 'rummy', 'singular', 'fishy', 'shady', 'suspect', 'suspicious', 'amusing', 'comic', 'comical', 'laughable', 'mirthful', 'risible']}
# {'word': 'furniture', 'synonyms': ['article of furniture', 'piece of furniture']}
# {'word': 'furthermore', 'synonyms': ['moreover', 'what is more']}
# {'word': 'future', 'synonyms': ['futurity', 'hereafter', 'time to come', 'next', 'succeeding', 'future tense']}
# {'word': 'gain', 'synonyms': ['amplification', 'bring in', 'clear', 'earn', 'make', 'pull in', 'realise', 'realize', 'take in', 'gather', 'addition', 'increase', 'acquire', 'win', 'derive', 'benefit', 'profit', 'arrive at', 'attain', 'hit', 'reach', 'put on', 'advance', 'gain ground', 'get ahead', 'make headway', 'pull ahead']}
# {'word': 'galaxy', 'synonyms': ['beetleweed', 'coltsfoot', 'galax', 'galax urceolata', 'wandflower', 'extragalactic nebula']}
# {'word': 'gallery', 'synonyms': ['art gallery', 'picture gallery', 'veranda', 'verandah', 'drift', 'heading']}
# {'word': 'game', 'synonyms': ['biz', 'plot', 'secret plan', 'gamey', 'gamy', 'gritty', 'mettlesome', 'spirited', 'spunky', 'back', 'bet on', 'gage', 'punt', 'stake', 'crippled', 'gimpy', 'halt', 'halting', 'lame']}
# {'word': 'gang', 'synonyms': ['bunch', 'crew', 'crowd', 'work party', 'mob', 'pack', 'ring', 'gang up']}
# {'word': 'gap', 'synonyms': ['break', 'disruption', 'interruption', 'opening', 'crack', 'spread', 'col', 'breach']}
# {'word': 'garage', 'synonyms': ['service department']}
# {'word': 'garden', 'synonyms': []}
# {'word': 'garlic', 'synonyms': ['allium sativum', 'ail']}
# {'word': 'gas', 'synonyms': ['natural gas', 'gasolene', 'gasoline', 'petrol', 'flatulence', 'flatulency', 'gaseous state', 'accelerator', 'accelerator pedal', 'gas pedal', 'gun', 'throttle', 'blow', 'bluster', 'boast', 'brag', 'gasconade', 'shoot a line', 'swash', 'tout', 'vaunt']}
# {'word': 'gate', 'synonyms': ['logic gate']}
# {'word': 'gather', 'synonyms': ['gathering', 'assemble', 'foregather', 'forgather', 'meet', 'collect', 'garner', 'pull together', 'gain', 'get together', 'pucker', 'tuck', 'accumulate', 'amass', 'conglomerate', 'cumulate', 'pile up']}
# {'word': 'gay', 'synonyms': ['homophile', 'queer', 'festal', 'festive', 'merry', 'jocund', 'jolly', 'jovial', 'mirthful', 'homo', 'homosexual', 'cheery', 'sunny', 'brave', 'braw']}
# {'word': 'gaze', 'synonyms': ['stare', 'regard']}
# {'word': 'gear', 'synonyms': ['pitch', 'gear mechanism', 'gearing', 'geartrain', 'power train', 'train', 'cogwheel', 'gear wheel', 'geared wheel', 'appurtenance', 'paraphernalia']}
# {'word': 'gender', 'synonyms': ['sex', 'sexuality', 'grammatical gender']}
# {'word': 'gene', 'synonyms': ['cistron', 'factor']}
# {'word': 'general', 'synonyms': ['full general', 'superior general', 'cosmopolitan', 'ecumenical', 'oecumenical', 'universal', 'world-wide', 'worldwide']}
# {'word': 'generally', 'synonyms': ['by and large', 'more often than not', 'mostly', 'broadly', 'broadly speaking', 'loosely', 'in general', 'in the main']}
# {'word': 'generate', 'synonyms': ['beget', 'bring forth', 'engender', 'father', 'get', 'mother', 'sire', 'give', 'render', 'return', 'yield']}
# {'word': 'generation', 'synonyms': ['genesis', 'multiplication', 'propagation', 'coevals', 'contemporaries']}
# {'word': 'genetic', 'synonyms': ['genetical', 'familial', 'hereditary', 'inherited', 'transmissible', 'transmitted', 'genic']}
# {'word': 'gentleman', 'synonyms': ["gentleman's gentleman", 'man', 'valet', 'valet de chambre']}
# {'word': 'gently', 'synonyms': ['mildly', 'lightly', 'softly']}
# {'word': 'german', 'synonyms': ['german language', 'high german']}
# {'word': 'gesture', 'synonyms': ['gesticulate', 'motion']}
# {'word': 'get', 'synonyms': ['catch', 'acquire', 'develop', 'grow', 'produce', 'bugger off', 'buzz off', 'fuck off', 'scram', 'have', 'suffer', 'sustain', 'beget', 'bring forth', 'engender', 'father', 'generate', 'mother', 'sire', 'make', 'amaze', 'baffle', 'beat', 'bewilder', 'dumbfound', 'flummox', 'gravel', 'mystify', 'nonplus', 'perplex', 'pose', 'puzzle', 'stick', 'stupefy', 'vex', 'receive', 'fix', 'pay back', 'pay off', 'aim', 'drive', 'experience', "get under one's skin", 'begin', 'commence', 'get down', 'set about', 'set out', 'start', 'start out', 'capture', 'become', 'go', 'arrest', 'find', 'incur', 'obtain', 'draw', 'contract', 'take', 'let', 'cause', 'induce', 'stimulate', 'arrive', 'come', 'bring', 'convey', 'fetch']}
# {'word': 'ghost', 'synonyms': ['haunt', 'obsess', 'ghostwrite', 'touch', 'trace', 'shade', 'specter', 'spectre', 'spook', 'wraith', 'ghostwriter']}
# {'word': 'giant', 'synonyms': ['behemoth', 'colossus', 'heavyweight', 'titan', 'giant star', 'goliath', 'monster', 'elephantine', 'gargantuan', 'jumbo', 'hulk', 'whale']}
# {'word': 'gift', 'synonyms': ['endowment', 'natural endowment', 'talent', 'give', 'present', 'empower', 'endow', 'endue', 'indue', 'invest', 'giving']}
# {'word': 'gifted', 'synonyms': ['talented']}
# {'word': 'girl', 'synonyms': ['girlfriend', 'lady friend', 'fille', 'miss', 'missy', 'young lady', 'young woman', 'female child', 'little girl', 'daughter']}
# {'word': 'girlfriend', 'synonyms': ['girl', 'lady friend']}
# {'word': 'give', 'synonyms': ['afford', 'yield', 'commit', 'consecrate', 'dedicate', 'devote', 'spring', 'springiness', 'impart', 'leave', 'pass on', 'ease up', 'give way', 'move over', 'render', 'feed', 'generate', 'return', 'throw', 'chip in', 'contribute', 'kick in', 'grant', 'pay', 'break', 'cave in', 'collapse', 'fall in', 'founder', 'hand', 'pass', 'reach', 'turn over', 'have', 'hold', 'make', 'establish', 'open', 'apply', 'gift', 'present', 'sacrifice']}
# {'word': 'given', 'synonyms': ['precondition', 'presumption', 'apt', 'disposed', 'minded', 'tending', 'granted']}
# {'word': 'glad', 'synonyms': ['happy', 'beaming', 'gladiola', 'gladiolus', 'sword lily']}
# {'word': 'glance', 'synonyms': ['glint', 'peek', "coup d'oeil", 'glimpse']}
# {'word': 'glass', 'synonyms': ['looking glass', 'field glass', 'spyglass', 'chalk', 'chicken feed', 'crank', 'deoxyephedrine', 'ice', 'meth', 'methamphetamine', 'methamphetamine hydrochloride', 'methedrine', 'shabu', 'trash', 'glass in', 'drinking glass', 'glass over', 'glaze', 'glaze over', 'glassful']}
# {'word': 'global', 'synonyms': ['planetary', 'world', 'world-wide', 'worldwide', 'ball-shaped', 'globose', 'globular', 'orbicular', 'spheric', 'spherical']}
# {'word': 'glove', 'synonyms': ['baseball glove', 'baseball mitt', 'mitt', 'boxing glove']}
# {'word': 'go', 'synonyms': ['proceed', 'run', 'depart', 'go away', 'function', 'operate', 'work', 'locomote', 'move', 'travel', 'belong', 'crack', 'fling', 'offer', 'pass', 'whirl', 'go game', 'buy the farm', "cash in one's chips", 'choke', 'conk', 'croak', 'decease', 'die', 'drop dead', 'exit', 'expire', 'give-up the ghost', 'kick the bucket', 'pass away', 'perish', 'pop off', 'snuff it', 'sound', 'lead', 'adam', 'cristal', 'disco biscuit', 'ecstasy', 'hug drug', 'x', 'xtc', 'endure', 'hold out', 'hold up', 'last', 'live', 'live on', 'survive', 'get going', 'start', 'break', 'break down', 'conk out', 'fail', 'give out', 'give way', 'go bad', 'run low', 'run short', 'spell', 'tour', 'turn', 'blend', 'blend in', 'rifle', 'become', 'get', 'plump', 'extend', 'fit']}
# {'word': 'goal', 'synonyms': ['end', 'destination', 'finish']}
# {'word': 'god', 'synonyms': ['graven image', 'idol', 'deity', 'divinity', 'immortal', 'supreme being']}
# {'word': 'gold', 'synonyms': ['atomic number 79', 'au', 'amber', 'aureate', 'gilded', 'gilt', 'golden']}
# {'word': 'golden', 'synonyms': ['favorable', 'favourable', 'lucky', 'prosperous', 'halcyon', 'aureate', 'gilded', 'gilt', 'gold', 'fortunate']}
# {'word': 'golf', 'synonyms': ['golf game']}
# {'word': 'good', 'synonyms': ['goodness', 'commodity', 'trade good', 'dear', 'near', 'effective', 'in effect', 'in force', 'beneficial', 'well', 'salutary', 'serious', 'just', 'upright', 'unspoiled', 'unspoilt', 'sound', 'honest', 'full', 'soundly', 'thoroughly', 'estimable', 'honorable', 'respectable', 'adept', 'expert', 'practiced', 'proficient', 'skilful', 'skillful', 'dependable', 'safe', 'secure', 'right', 'ripe']}
# {'word': 'government', 'synonyms': ['administration', 'governance', 'governing', 'government activity', 'authorities', 'regime', 'political science', 'politics']}
# {'word': 'governor', 'synonyms': ['regulator']}
# {'word': 'grab', 'synonyms': ['catch', 'snap', 'snatch', 'take hold of', 'seize', 'snaffle', 'snap up']}
# {'word': 'grade', 'synonyms': ['order', 'place', 'range', 'rank', 'rate', 'mark', 'score', 'ground level', 'gradation', 'class', 'course', 'form', 'grad', 'level', 'tier', 'degree']}
# {'word': 'gradually', 'synonyms': ['bit by bit', 'step by step']}
# {'word': 'graduate', 'synonyms': ['alum', 'alumna', 'alumnus', 'grad', 'calibrate', 'fine-tune', 'postgraduate']}
# {'word': 'grain', 'synonyms': ['texture', 'ingrain', 'granulate', 'metric grain', 'caryopsis', 'cereal', 'food grain']}
# {'word': 'grand', 'synonyms': ['expansive', 'heroic', 'distinguished', 'imposing', 'magisterial', 'grand piano', 'august', 'lordly', 'elevated', 'exalted', 'high-flown', 'high-minded', 'idealistic', 'lofty', 'noble-minded', 'rarefied', 'rarified', 'sublime', '1000', 'chiliad', 'g', 'k', 'm', 'one thousand', 'thou', 'thousand', 'yard', 'deluxe', 'gilded', 'lush', 'luxurious', 'opulent', 'princely', 'sumptuous', 'fantastic', 'howling', 'marvellous', 'marvelous', 'rattling', 'terrific', 'tremendous', 'wonderful', 'wondrous']}
# {'word': 'grandfather', 'synonyms': ['gramps', 'grandad', 'granddad', 'granddaddy', 'grandpa']}
# {'word': 'grandmother', 'synonyms': ['gran', 'grandma', 'grannie', 'granny', 'nan', 'nanna']}
# {'word': 'grant', 'synonyms': ['hiram ulysses grant', 'president grant', 'ulysses grant', 'ulysses s. grant', 'ulysses simpson grant', 'award', 'subsidisation', 'subsidization', 'allow', 'assignment', 'duncan grant', 'duncan james corrow grant', 'give', 'concession', 'cede', 'concede', 'yield', 'accord', 'allot', 'cary grant', 'deed over']}
# {'word': 'grass', 'synonyms': ['supergrass', 'grass over', 'eatage', 'forage', 'pasturage', 'pasture', 'betray', 'denounce', 'give away', 'rat', 'shit', 'shop', 'snitch', 'stag', 'tell on', 'dope', 'gage', 'green goddess', 'locoweed', 'mary jane', 'pot', 'sens', 'sess', 'skunk', 'smoke', 'weed', 'gunter grass', 'gunter wilhelm grass']}
# {'word': 'grave', 'synonyms': ['grievous', 'heavy', 'weighty', 'grave accent', 'sedate', 'sober', 'solemn', 'engrave', 'inscribe', 'scratch', 'sculpt', 'sculpture', 'tomb', 'dangerous', 'life-threatening', 'serious', 'severe']}
# {'word': 'gray', 'synonyms': ['grey', 'louis harold gray', 'asa gray', 'gray-haired', 'gray-headed', 'grey-haired', 'grey-headed', 'grizzly', 'hoar', 'hoary', 'white-haired', 'gy', 'thomas gray', 'robert gray', 'grayness', 'greyness', 'grayish', 'greyish']}
# {'word': 'great', 'synonyms': ['big', 'enceinte', 'expectant', 'gravid', 'heavy', 'large', 'with child', 'outstanding', 'capital', 'majuscule', 'bang-up', 'bully', 'corking', 'cracking', 'dandy', 'groovy', 'keen', 'neat', 'nifty', 'not bad', 'old', 'peachy', 'slap-up', 'smashing', 'swell']}
# {'word': 'greatest', 'synonyms': ['sterling', 'superlative']}
# {'word': 'green', 'synonyms': ['putting green', 'putting surface', 'common', 'commons', 'park', 'dark-green', 'greenish', 'light-green', 'william green', 'greens', 'leafy vegetable', 'cat valium', 'honey oil', 'jet', 'k', 'special k', 'super acid', 'super c', 'greenness', 'viridity', 'green river', 'fleeceable', 'gullible', 'immature', 'unripe', 'unripened']}
# {'word': 'grocery', 'synonyms': ['food market', 'grocery store', 'market', 'foodstuff']}
# {'word': 'ground', 'synonyms': ['land', 'soil', 'background', 'reason', 'run aground', 'basis', 'footing', 'prime', 'undercoat', 'earth', 'anchor', 'base', 'establish', 'found', 'strand', 'dry land', 'solid ground', 'terra firma', 'flat coat', 'primer', 'primer coat', 'priming', 'priming coat']}
# {'word': 'group', 'synonyms': ['mathematical group', 'aggroup', 'grouping', 'chemical group', 'radical']}
# {'word': 'grow', 'synonyms': ['turn', 'maturate', 'mature', 'acquire', 'develop', 'get', 'produce', 'arise', 'originate', 'rise', 'spring up', 'uprise', 'farm', 'raise']}
# {'word': 'growing', 'synonyms': ['development', 'growth', 'maturation', 'ontogenesis', 'ontogeny']}
# {'word': 'growth', 'synonyms': ['emergence', 'outgrowth', 'development', 'growing', 'maturation', 'ontogenesis', 'ontogeny', 'increase', 'increment']}
# {'word': 'guarantee', 'synonyms': ['vouch', 'warrant', 'undertake', 'warrantee', 'warranty', 'assure', 'ensure', 'insure', 'secure', 'guaranty']}
# {'word': 'guard', 'synonyms': ['safety', 'safety device', 'guard duty', 'sentry duty', 'sentry go', 'precaution', 'safeguard', 'ward', 'defend', 'hold']}
# {'word': 'guess', 'synonyms': ['dead reckoning', 'guessing', 'guesswork', 'shot', 'infer', 'approximate', 'estimate', 'gauge', 'judge', 'imagine', 'opine', 'reckon', 'suppose', 'think', 'conjecture', 'hypothesis', 'speculation', 'supposition', 'surmisal', 'surmise', 'hazard', 'pretend', 'venture']}
# {'word': 'guest', 'synonyms': ['invitee', 'client', 'node', 'edgar albert guest', 'edgar guest']}
# {'word': 'guide', 'synonyms': ['guide on', 'steer', 'conduct', 'direct', 'lead', 'take', 'guidebook', 'usher', 'pathfinder', 'scout', 'draw', 'pass', 'run', 'template', 'templet', 'channelise', 'channelize', 'head', 'maneuver', 'manoeuver', 'manoeuvre', 'point']}
# {'word': 'guideline', 'synonyms': ['road map', 'guidepost', 'rule of thumb']}
# {'word': 'guilty', 'synonyms': ['hangdog', 'shamed', 'shamefaced']}
# {'word': 'gun', 'synonyms': ['grease gun', 'artillery', 'heavy weapon', 'ordnance', 'gunman', 'accelerator', 'accelerator pedal', 'gas', 'gas pedal', 'throttle', 'gun for hire', 'gunslinger', 'hired gun', 'hit man', 'hitman', 'shooter', 'torpedo', 'triggerman']}
# {'word': 'guy', 'synonyms': ['blackguard', 'jest at', 'laugh at', 'make fun', 'poke fun', 'rib', 'ridicule', 'roast', 'guy cable', 'guy rope', 'guy wire', 'bozo', 'cat', 'hombre', 'sod']}
# {'word': 'habit', 'synonyms': ['wont', 'riding habit', 'use', 'drug abuse', 'substance abuse']}
# {'word': 'habitat', 'synonyms': ['home ground']}
# {'word': 'hair', 'synonyms': ["hair's-breadth", 'hairsbreadth', 'whisker', 'pilus', 'haircloth', 'fuzz', 'tomentum']}
# {'word': 'half', 'synonyms': ['one-half']}
# ...
# {'word': 'voice', 'synonyms': ['phonation', 'vocalisation', 'vocalism', 'vocalization', 'vox', 'part', 'interpreter', 'representative', 'spokesperson', 'articulation', 'sound', 'vocalise', 'vocalize']}
# {'word': 'volume', 'synonyms': ['book', 'bulk', 'mass', 'intensity', 'loudness']}
# {'word': 'volunteer', 'synonyms': ['unpaid worker', 'offer', 'unpaid', 'military volunteer', 'voluntary', 'tennessean']}
# {'word': 'vote', 'synonyms': ['right to vote', 'suffrage', 'ballot', 'balloting', 'voting', 'voter turnout']}
# {'word': 'voter', 'synonyms': ['elector']}
# {'word': 'v', 'synonyms': ['volt', 'atomic number 23', 'vanadium', '5', 'five', 'cinque', 'fin', 'fivesome', 'little phoebe', 'pentad', 'phoebe', 'quint', 'quintet', 'quintuplet']}
# {'word': 'vulnerable', 'synonyms': []}
# {'word': 'wage', 'synonyms': ['engage', 'earnings', 'pay', 'remuneration', 'salary']}
# {'word': 'wait', 'synonyms': ['waiting', 'await', 'expect', 'look', 'delay', 'hold', 'postponement', 'time lag', 'hold back', 'hold off', 'waitress']}
# {'word': 'wake', 'synonyms': ['aftermath', 'backwash', 'arouse', 'awake', 'awaken', 'come alive', 'wake up', 'waken', 'viewing', 'rouse', 'fire up', 'heat', 'ignite', 'inflame', 'stir up', 'wake island']}
# {'word': 'walk', 'synonyms': ['walking', 'walk of life', 'take the air', 'manner of walking', 'base on balls', 'pass', 'paseo', 'walkway']}
# {'word': 'wall', 'synonyms': ['bulwark', 'rampart', 'paries', 'fence', 'fence in', 'palisade', 'surround']}
# {'word': 'wander', 'synonyms': ['cast', 'drift', 'ramble', 'range', 'roam', 'roll', 'rove', 'stray', 'swan', 'tramp', 'vagabond', 'meander', 'thread', 'weave', 'wind', 'betray', 'cheat', 'cheat on', 'cuckold', 'digress', 'divagate']}
# {'word': 'want', 'synonyms': ['need', 'require', 'deprivation', 'neediness', 'privation', 'deficiency', 'lack', 'wish', 'wishing', 'desire']}
# {'word': 'war', 'synonyms': ['warfare', 'state of war']}
# {'word': 'warm', 'synonyms': ['quick', 'ardent', 'strong', 'warmly', 'warm up']}
# {'word': 'warn', 'synonyms': ['admonish', 'discourage', 'monish']}
# {'word': 'warning', 'synonyms': ['admonition', 'monition', 'word of advice', 'admonitory', 'cautionary', 'exemplary', 'monitory']}
# {'word': 'wash', 'synonyms': ['washout', 'dampen', 'moisten', 'airstream', 'backwash', 'race', 'slipstream', 'laundry', 'washables', 'washing', 'launder', 'wash away', 'wash off', 'wash out', 'lavation', 'lap', 'lave', 'rinse', 'dry wash', 'wash drawing']}
# {'word': 'waste', 'synonyms': ['emaciate', 'macerate', 'run off', 'blow', 'squander', 'rot', 'do in', 'knock off', 'liquidate', 'neutralise', 'neutralize', 'desolate', 'devastate', 'lay waste to', 'ravage', 'scourge', 'languish', 'pine away', 'godforsaken', 'wild', 'barren', 'wasteland', 'dissipation', 'wastefulness', 'consume', 'ware', 'permissive waste', 'thriftlessness', 'waste material', 'waste matter', 'waste product']}
# {'word': 'watch', 'synonyms': ['lookout', 'lookout man', 'picket', 'scout', 'sentinel', 'sentry', 'spotter', 'catch', 'see', 'take in', 'view', 'ascertain', 'check', 'determine', 'find out', 'learn', 'vigil', 'look on', 'ticker', 'follow', 'keep an eye on', 'observe', 'watch over', 'look out', 'watch out']}
# {'word': 'water', 'synonyms': ['body of water', 'water supply', 'water system', 'h2o', 'pee', 'piddle', 'piss', 'urine', 'weewee', 'irrigate']}
# {'word': 'wave', 'synonyms': ['beckon', 'brandish', 'flourish', 'undulation', 'moving ridge', 'flap', 'roll', 'undulate', 'curl', 'wafture', 'waving']}
# {'word': 'way', 'synonyms': ['elbow room', 'room', 'path', 'way of life', 'agency', 'means', 'direction', 'right smart', 'fashion', 'manner', 'mode', 'style']}
# {'word': 'we', 'synonyms': []}
# {'word': 'weak', 'synonyms': ['faint', 'light', 'unaccented', 'washy', 'watery', 'fallible', 'frail', 'imperfect', 'debile', 'decrepit', 'feeble', 'infirm', 'rickety', 'sapless', 'weakly']}
# {'word': 'wealth', 'synonyms': ['wealthiness', 'riches']}
# {'word': 'wealthy', 'synonyms': ['affluent', 'flush', 'loaded', 'moneyed', 'substantial']}
# {'word': 'weapon', 'synonyms': ['arm', 'weapon system', 'artillery']}
# {'word': 'wear', 'synonyms': ['fag', 'fag out', 'fatigue', 'jade', 'outwear', 'tire', 'tire out', 'wear down', 'wear out', 'wear upon', 'weary', 'have on', 'wearing', 'bear', 'break', 'bust', 'fall apart', 'assume', 'don', 'get into', 'put on', 'article of clothing', 'clothing', 'habiliment', 'vesture', 'wearable', 'wear off', 'wear thin', 'endure', 'hold out']}
# {'word': 'weather', 'synonyms': ['brave', 'brave out', 'endure', 'upwind', 'atmospheric condition', 'conditions', 'weather condition']}
# {'word': 'wedding', 'synonyms': ['hymeneals', 'nuptials', 'wedding ceremony', 'marriage', 'marriage ceremony', 'wedding party']}
# {'word': 'week', 'synonyms': ['workweek', 'hebdomad', 'calendar week']}
# {'word': 'weekend', 'synonyms': []}
# {'word': 'weekly', 'synonyms': ['hebdomadal', 'hebdomadary', 'each week', 'every week', 'hebdomadally']}
# {'word': 'weigh', 'synonyms': ['consider', 'count', 'press', 'librate', 'matter']}
# {'word': 'weight', 'synonyms': ['system of weights', 'weightiness', 'exercising weight', 'free weight', 'weighting', 'burden', 'burthen', 'weight down', 'angle', 'slant', 'weight unit']}
# {'word': 'welcome', 'synonyms': ['receive']}
# {'word': 'welfare', 'synonyms': ['eudaemonia', 'eudaimonia', 'upbeat', 'well-being', 'wellbeing', 'public assistance', 'social welfare', 'benefit']}
# {'word': 'well', 'synonyms': ['advantageously', 'good', 'easily', 'considerably', 'substantially', 'fountainhead', 'wellspring', 'intimately', 'swell', 'comfortably']}
# {'word': 'west', 'synonyms': ['mae west', 'western united states', 'benjamin west', 'occident', 'cicily isabel fairfield', 'dame rebecca west', 'rebecca west', 'due west', 'w', 'westward']}
# {'word': 'western', 'synonyms': ['westerly', 'western sandwich', 'horse opera']}
# {'word': 'wet', 'synonyms': ['besotted', 'blind drunk', 'blotto', 'cockeyed', 'crocked', 'fuddled', 'loaded', 'pie-eyed', 'pissed', 'pixilated', 'plastered', 'slopped', 'sloshed', 'smashed', 'soaked', 'soused', 'sozzled', 'squiffy', 'stiff', 'tight', 'lactating', 'moisture']}
# {'word': 'what', 'synonyms': []}
# {'word': 'whatever', 'synonyms': ['any', 'whatsoever']}
# {'word': 'wheel', 'synonyms': ['roll', 'rack', 'wheel around', 'bicycle', 'bike', 'cycle', 'pedal', 'roulette wheel', 'steering wheel']}
# {'word': 'when', 'synonyms': []}
# {'word': 'whenever', 'synonyms': []}
# {'word': 'where', 'synonyms': []}
# {'word': 'whereas', 'synonyms': []}
# {'word': 'whether', 'synonyms': []}
# {'word': 'which', 'synonyms': []}
# {'word': 'while', 'synonyms': ['patch', 'piece', 'spell']}
# {'word': 'whisper', 'synonyms': ['susurration', 'voicelessness', 'whispering', 'rustle', 'rustling']}
# {'word': 'white', 'synonyms': ['caucasian', 'white person', 'e. b. white', 'elwyn brooks white', 'stanford white', 'white river', 'flannel', 'gabardine', 'tweed', 'ashen', 'blanched', 'bloodless', 'livid', 'lily-white', 'snowy', 'albumen', 'egg white', 'ovalbumin', 'andrew d. white', 'andrew dickson white', 'whiten', 'blank', 'clean', 'patrick victor martindale white', 'patrick white', 'white-hot', 'whiteness', 'edward d. white', 'edward douglas white jr.', 'edward white', 't. h. white', 'theodore harold white', 'whitened']}
# {'word': 'who', 'synonyms': ['w.h.o.', 'world health organization']}
# {'word': 'whole', 'synonyms': ['unharmed', 'unhurt', 'unscathed', 'unit', 'solid', 'unanimous', 'hale', 'all', 'altogether', 'completely', 'entirely', 'right', 'totally', 'wholly']}
# {'word': 'whom', 'synonyms': []}
# {'word': 'whose', 'synonyms': []}
# {'word': 'why', 'synonyms': ['wherefore']}
# {'word': 'wide', 'synonyms': ['wide of the mark', 'wide-eyed', 'astray', 'broad', 'full', 'wide-cut', 'widely', 'across-the-board', 'all-embracing', 'all-encompassing', 'all-inclusive', 'blanket', 'encompassing', 'extensive', 'panoptic', 'spacious']}
# {'word': 'widely', 'synonyms': ['wide']}
# {'word': 'widespread', 'synonyms': ['far-flung']}
# {'word': 'wife', 'synonyms': ['married woman']}
# {'word': 'wild', 'synonyms': ['rampantly', 'barbarian', 'barbaric', 'savage', 'uncivilised', 'uncivilized', 'natural state', 'state of nature', 'baseless', 'groundless', 'idle', 'unfounded', 'unwarranted', 'untamed', 'fantastic', 'wilderness', 'raving mad', 'hazardous', 'risky', 'godforsaken', 'waste', 'angry', 'furious', 'raging', 'tempestuous', 'crazy', 'dotty', 'gaga', 'violent']}
# {'word': 'will', 'synonyms': ['testament', 'volition', 'bequeath', 'leave']}
# {'word': 'willing', 'synonyms': ['uncoerced', 'unforced', 'volition']}
# {'word': 'win', 'synonyms': ['bring home the bacon', 'come through', 'deliver the goods', 'succeed', 'profits', 'winnings', 'acquire', 'gain', 'advance', 'gain ground', 'get ahead', 'make headway', 'pull ahead', 'earn', 'garner']}
# {'word': 'wind', 'synonyms': ['hoist', 'lift', 'nose', 'scent', 'breaking wind', 'fart', 'farting', 'flatus', 'wreathe', 'idle words', 'jazz', 'malarkey', 'malarky', 'nothingness', 'roll', 'twine', 'wrap', 'meander', 'thread', 'wander', 'weave', 'curve', 'twist', 'winding', 'wind instrument', 'air current', 'current of air', 'wind up', 'confidential information', 'hint', 'lead', 'steer', 'tip']}
# {'word': 'window', 'synonyms': ['windowpane']}
# {'word': 'wine', 'synonyms': ['wine-colored', 'wine-coloured', 'vino']}
# {'word': 'wing', 'synonyms': ['fly', 'annex', 'annexe', 'extension', 'backstage', 'offstage', 'fender', 'flank']}
# {'word': 'winner', 'synonyms': ['achiever', 'succeeder', 'success', 'victor']}
# {'word': 'winter', 'synonyms': ['overwinter', 'wintertime']}
# {'word': 'wipe', 'synonyms': ['pass over', 'rub']}
# {'word': 'wire', 'synonyms': ['telegram', 'electrify', 'conducting wire', 'cable', 'telegraph']}
# {'word': 'wisdom', 'synonyms': ['wiseness', 'soundness', 'sapience', 'wisdom of solomon']}
# {'word': 'wise', 'synonyms': ['stephen samuel wise', 'fresh', 'impertinent', 'impudent', 'overbold', 'sassy', 'saucy', 'smart', 'isaac mayer wise', 'knowing', 'wise to', 'heady', 'judicious']}
# {'word': 'wish', 'synonyms': ['care', 'like', 'wish well', 'compliments', 'regard', 'bid', 'indirect request', 'want', 'wishing']}
# {'word': 'with', 'synonyms': []}
# {'word': 'withdraw', 'synonyms': ['adjourn', 'retire', 'remove', 'take', 'take away', 'call back', 'call in', 'recall', 'bow out', 'draw back', 'move back', 'pull away', 'pull back', 'recede', 'retreat', 'seclude', 'sequester', 'sequestrate', 'swallow', 'take back', 'unsay', 'back away', 'back out', 'crawfish', 'crawfish out', "pull in one's horns", 'disengage', 'draw', 'draw off', 'take out']}
# {'word': 'within', 'synonyms': ['inside']}
# {'word': 'without', 'synonyms': []}
# {'word': 'witness', 'synonyms': ['attestant', 'attestator', 'attestor', 'informant', 'witnesser', 'find', 'see', 'looker', 'spectator', 'viewer', 'watcher']}
# {'word': 'woman', 'synonyms': ['char', 'charwoman', 'cleaning lady', 'cleaning woman', 'adult female', 'fair sex', 'womanhood']}
# {'word': 'wonder', 'synonyms': ['marvel', 'enquire', 'inquire', 'admiration', 'wonderment', 'curiosity', 'question']}
# {'word': 'wonderful', 'synonyms': ['fantastic', 'grand', 'howling', 'marvellous', 'marvelous', 'rattling', 'terrific', 'tremendous', 'wondrous']}
# {'word': 'wood', 'synonyms': ['grant wood', 'forest', 'woods', 'natalie wood', 'woodwind', 'woodwind instrument', 'sir henry joseph wood', 'sir henry wood', 'ellen price wood', 'mrs. henry wood']}
# {'word': 'wooden', 'synonyms': []}
# {'word': 'word', 'synonyms': ['logos', 'son', 'intelligence', 'news', 'tidings', 'discussion', 'give-and-take', 'countersign', 'parole', 'password', 'watchword', 'bible', 'book', 'christian bible', 'good book', 'holy scripture', 'holy writ', 'scripture', 'word of god', 'word of honor', 'articulate', 'formulate', 'give voice', 'phrase']}
# {'word': 'work', 'synonyms': ['knead', 'function', 'go', 'operate', 'run', 'do work', 'study', 'act upon', 'influence', 'forge', 'form', 'mold', 'mould', 'shape', 'bring', 'make for', 'play', 'wreak', 'employment', 'put to work', 'figure out', 'lick', 'puzzle out', 'solve', 'work out', 'piece of work', 'act', 'exploit', 'make', 'crop', 'cultivate', 'process', 'work on', 'workplace', 'ferment', 'body of work', 'oeuvre', 'exercise', 'sour', 'turn']}
# {'word': 'worker', 'synonyms': ['prole', 'proletarian', 'actor', 'doer']}
# {'word': 'working', 'synonyms': ['on the job', 'workings', 'functional', 'operative', 'running']}
# {'word': 'works', 'synonyms': ['workings', 'industrial plant', 'plant', 'deeds', 'full treatment', 'kit and boodle', 'kit and caboodle', 'whole caboodle', 'whole kit', 'whole kit and boodle', 'whole kit and caboodle', 'whole shebang', 'whole works']}
# {'word': 'workshop', 'synonyms': ['shop']}
# {'word': 'world', 'synonyms': ['domain', 'populace', 'public', 'reality', 'earth', 'globe', 'global', 'planetary', 'world-wide', 'worldwide', 'earthly concern', 'worldly concern', 'cosmos', 'creation', 'existence', 'macrocosm', 'universe', 'human beings', 'human race', 'humanity', 'humankind', 'humans', 'man', 'mankind']}
# {'word': 'worried', 'synonyms': ['disquieted', 'distressed', 'disturbed', 'upset', 'apprehensive']}
# {'word': 'worry', 'synonyms': ['concern', 'interest', 'occupy', 'headache', 'vexation', 'care', 'vex', 'trouble']}
# {'word': 'worth', 'synonyms': ['charles frederick worth', 'deserving']}
# {'word': 'would', 'synonyms': []}
# {'word': 'wound', 'synonyms': ['combat injury', 'injury', 'lesion', 'bruise', 'hurt', 'injure', 'offend', 'spite', 'wounding']}
# {'word': 'wrap', 'synonyms': ['wrap up', 'roll', 'twine', 'wind', 'wrapper', 'wrapping', 'enclose', 'enfold', 'envelop', 'enwrap']}
# {'word': 'write', 'synonyms': ['drop a line', 'compose', 'indite', 'pen', 'spell', 'save']}
# {'word': 'writer', 'synonyms': ['author']}
# {'word': 'writing', 'synonyms': ['piece of writing', 'written material', 'authorship', 'composition', 'penning', 'committal to writing']}
# {'word': 'wrong', 'synonyms': ['wrongfulness', 'amiss', 'awry', 'haywire', 'damage', 'legal injury', 'incorrect', 'ill-timed', 'unseasonable', 'untimely', 'incorrectly', 'wrongly', 'improper', 'faulty']}
# {'word': 'yard', 'synonyms': ['cubic yard', 'pace', '1000', 'chiliad', 'g', 'grand', 'k', 'm', 'one thousand', 'thou', 'thousand', 'railway yard', 'railyard', 'curtilage', 'grounds']}
# {'word': 'yeah', 'synonyms': ['yea']}
# {'word': 'year', 'synonyms': ['class', 'twelvemonth', 'yr']}
# {'word': 'yell', 'synonyms': ['call', 'cry', 'holler', 'hollo', 'scream', 'shout', 'shout out', 'squall', 'outcry', 'vociferation']}
# {'word': 'yellow', 'synonyms': ['xanthous', 'yellowish', 'yellowness', 'scandalmongering', 'sensationalistic', 'chicken', 'chickenhearted', 'lily-livered', 'white-livered', 'yellow-bellied', 'icteric', 'jaundiced', 'yellowed']}
# {'word': 'yes', 'synonyms': []}
# {'word': 'yesterday', 'synonyms': []}
# {'word': 'yet', 'synonyms': ['so far', 'even', 'still', 'all the same', 'at the same time', 'even so', 'however', 'nevertheless', 'nonetheless', 'notwithstanding', 'withal', 'in time', 'as yet', 'heretofore', 'hitherto', 'thus far', 'til now', 'until now', 'up to now']}
# {'word': 'yield', 'synonyms': ['issue', 'payoff', 'proceeds', 'return', 'take', 'takings', 'afford', 'give', 'give way', 'ease up', 'move over', 'buckle under', 'give in', 'knuckle under', 'succumb', 'generate', 'render', 'relent', 'soften', 'cede', 'concede', 'grant', 'output', 'production', 'bear', 'pay', 'fruit']}
# {'word': 'you', 'synonyms': []}
# {'word': 'young', 'synonyms': ['new', 'whitney moore young jr.', 'whitney young', 'brigham young', 'thomas young', 'vernal', 'youthful', 'cy young', 'danton true young', 'loretta young', 'offspring', 'youth', 'immature', 'unseasoned', 'untested', 'untried', 'edward young', 'lester willis young', 'pres young']}
# {'word': 'your', 'synonyms': []}
# {'word': 'yours', 'synonyms': []}
# {'word': 'yourself', 'synonyms': []}
# {'word': 'youth', 'synonyms': ['early days', 'juvenility', 'youthfulness', 'young', 'spring chicken', 'young person', 'younker']}
# {'word': 'zone', 'synonyms': ['district', 'geographical zone', 'partition', 'zona']}
